# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 311 Data

# %%
df311_og = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
df311_og.tail()
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 164488    51836466  09/10/2021 09:40:00 PM  09/11/2021 12:00:00 PM   DSNY
# 164489    51836565  09/10/2021 06:06:00 PM  09/11/2021 12:00:00 PM   DSNY
# 164490    51836576  09/10/2021 11:03:00 PM  09/11/2021 12:00:00 PM   DSNY
# 164491    51912087  09/17/2021 08:24:00 PM  09/20/2021 12:00:00 PM   DSNY
# 164492    51912497  09/17/2021 12:43:00 PM  09/22/2021 12:00:00 PM   DSNY
#
#                      Agency Name    Complaint Type         Descriptor  \
# 164488  Department of Sanitation  Dirty Conditions  E3 Dirty Sidewalk
# 164489  Department of Sanitation  Dirty Conditions  E3 Dirty Sidewalk
# 164490  Department of Sanitation  Dirty Conditions  E3 Dirty Sidewalk
# 164491  Department of Sanitation  Dirty Conditions   E5 Loose Rubbish
# 164492  Department of Sanitation  Dirty Conditions  E3 Dirty Sidewalk
#
#        Location Type  Incident Zip       Incident Address  ... Vehicle Type  \
# 164488      Sidewalk       11214.0         2172 86 STREET  ...          NaN
# 164489      Sidewalk       11231.0    146 COLUMBIA STREET  ...          NaN
# 164490      Sidewalk       11229.0  2272 EAST   17 STREET  ...          NaN
# 164491      Sidewalk           NaN                    NaN  ...          NaN
# 164492      Sidewalk           NaN                    NaN  ...          NaN
#
#        Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 164488                  NaN                   NaN                 NaN
# 164489                  NaN                   NaN                 NaN
# 164490                  NaN                   NaN                 NaN
# 164491                  NaN                   NaN                 NaN
# 164492                  NaN                   NaN                 NaN
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 164488                      NaN       NaN                    NaN  40.602252
# 164489                      NaN       NaN                    NaN  40.686904
# 164490                      NaN       NaN                    NaN  40.595274
# 164491                      NaN       NaN                    NaN        NaN
# 164492                      NaN       NaN                    NaN        NaN
#
#         Longitude                                  Location
# 164488 -73.994325  (40.602251784945565, -73.99432455291887)
# 164489 -74.001806   (40.68690380398603, -74.00180647759399)
# 164490 -73.953813   (40.59527360176615, -73.95381259192706)
# 164491        NaN                                       NaN
# 164492        NaN                                       NaN
#
# [5 rows x 41 columns]

# %%
df311 = df311_og[['Created Date','Borough','Complaint Type','Descriptor','Location Type','Incident Zip','Community Board', 'Location']]

# %% [markdown]
# #### Clearning Community District Column for a Merge

# %%
df311['Borough'].replace({'BROOKLYN':'BK',"QUEENS":'QN','BRONX':'BX','MANHATTAN':'MN','STATEN ISLAND':'SI'},inplace=True)
df311['CD'] = df311.Borough + df311['Community Board'].str[0:2]
df311.drop(['Borough','Community Board'],axis=1,inplace=True)
df311.head()
# Out:
#              Created Date    Complaint Type               Descriptor  \
# 0  05/03/2021 06:54:00 AM  Dirty Conditions        E3 Dirty Sidewalk
# 1  05/02/2021 08:26:00 AM  Dirty Conditions        E3 Dirty Sidewalk
# 2  05/03/2021 10:35:00 AM  Dirty Conditions     E1 Improper Disposal
# 3  05/02/2021 02:34:00 PM  Dirty Conditions  E3A Dirty Area/Alleyway
# 4  05/02/2021 03:03:00 PM  Dirty Conditions        E3 Dirty Sidewalk
#
#   Location Type  Incident Zip                                  Location    CD
# 0      Sidewalk       11216.0    (40.68347186202379, -73.9539209649856)  BK03
# 1      Sidewalk       11105.0     (40.777907404785, -73.90745125248668)  QN01
# 2      Sidewalk       10452.0   (40.83393144965909, -73.92882432434307)  BX04
# 3           Lot       10011.0   (40.73463243696263, -73.99644940675921)  MN02
# 4      Sidewalk       10038.0  (40.706866299284606, -74.00699002392852)  MN01

# %% [markdown]
# #### Temporal Dimension

# %%
import datetime

# %%
df311['Created Date']= pd.to_datetime(df311['Created Date'])

# %%
df311.head()
# Out:
#          Created Date    Complaint Type               Descriptor  \
# 0 2021-05-03 06:54:00  Dirty Conditions        E3 Dirty Sidewalk
# 1 2021-05-02 08:26:00  Dirty Conditions        E3 Dirty Sidewalk
# 2 2021-05-03 10:35:00  Dirty Conditions     E1 Improper Disposal
# 3 2021-05-02 14:34:00  Dirty Conditions  E3A Dirty Area/Alleyway
# 4 2021-05-02 15:03:00  Dirty Conditions        E3 Dirty Sidewalk
#
#   Location Type  Incident Zip                                  Location    CD
# 0      Sidewalk       11216.0    (40.68347186202379, -73.9539209649856)  BK03
# 1      Sidewalk       11105.0     (40.777907404785, -73.90745125248668)  QN01
# 2      Sidewalk       10452.0   (40.83393144965909, -73.92882432434307)  BX04
# 3           Lot       10011.0   (40.73463243696263, -73.99644940675921)  MN02
# 4      Sidewalk       10038.0  (40.706866299284606, -74.00699002392852)  MN01

# %%
list_of_months = pd.date_range('2017-01-01','2021-12-31' , freq='1M')-pd.offsets.MonthBegin(1)
len(list_of_months)
max(list_of_months)
# Out:
# Timestamp('2021-12-01 00:00:00')

# %%
df311_final = pd.DataFrame(columns=df311.columns)
for month in list_of_months:
    df311['month'] = month
    df311_final = pd.concat([df311_final, df311])

df311_final.shape
# Out:
# (9869580, 8)

# %%
len(df311_final['month'].unique())
#makes sense because 12 months x 5 years (2017-2021)
# Out:
# 60

# %%
df311_final['Month'] = df311_final['month'].dt.to_period('M')

# %%
df311_final['Month'] = df311_final['Month'].values.astype('datetime64[M]')

# %%
df311_final['Month']=pd.to_datetime(df311_final['Month'], format='%Y-%m')

# %%
df311_final.dtypes
# Out:
# Created Date      datetime64[ns]
# Complaint Type            object
# Descriptor                object
# Location Type             object
# Incident Zip             float64
# Location                  object
# CD                        object
# month             datetime64[ns]
# Month             datetime64[ns]
# dtype: object

# %%
df311_final = df311_final[['Month','CD','Complaint Type','Descriptor','Location Type','Incident Zip','Location']]
df311_final.head()
# Out:
#        Month    CD    Complaint Type               Descriptor Location Type  \
# 0 2017-01-01  BK03  Dirty Conditions        E3 Dirty Sidewalk      Sidewalk
# 1 2017-01-01  QN01  Dirty Conditions        E3 Dirty Sidewalk      Sidewalk
# 2 2017-01-01  BX04  Dirty Conditions     E1 Improper Disposal      Sidewalk
# 3 2017-01-01  MN02  Dirty Conditions  E3A Dirty Area/Alleyway           Lot
# 4 2017-01-01  MN01  Dirty Conditions        E3 Dirty Sidewalk      Sidewalk
#
#    Incident Zip                                  Location
# 0       11216.0    (40.68347186202379, -73.9539209649856)
# 1       11105.0     (40.777907404785, -73.90745125248668)
# 2       10452.0   (40.83393144965909, -73.92882432434307)
# 3       10011.0   (40.73463243696263, -73.99644940675921)
# 4       10038.0  (40.706866299284606, -74.00699002392852)

# %%
#df311_final.to_csv('311.csv')

# %% [markdown]
# # Rating Data

# %%
rating_og = pd.read_csv('Scorecard_Ratings.csv')
rating_og.head()
# Out:
#        Month    Borough  Community Board District Cleaning Section  \
# 0  2020 / 08  Manhattan                1     MN01            MN011
# 1  2020 / 08  Manhattan                1     MN01            MN013
# 2  2020 / 08  Manhattan               10     MN10            MN101
# 3  2020 / 08  Manhattan               10     MN10            MN103
# 4  2020 / 08  Manhattan               10     MN10            MN104
#
#    Acceptable Streets %  Acceptable Sidewalks %  \
# 0                100.00                   100.0
# 1                100.00                   100.0
# 2                 88.00                   100.0
# 3                 91.67                   100.0
# 4                 96.00                    96.0
#
#    Acceptable Streets % - Previous Month  \
# 0                                    NaN
# 1                                    NaN
# 2                                  76.00
# 3                                  60.87
# 4                                  56.00
#
#    Acceptable Sidewalks % - Previous Month  \
# 0                                      NaN
# 1                                      NaN
# 2                                     92.0
# 3                                    100.0
# 4                                     96.0
#
#    Acceptable Streets % - Previous Year  \
# 0                                 96.15
# 1                                100.00
# 2                                 92.00
# 3                                 96.30
# 4                                100.00
#
#    Acceptable Sidewalks % - Previous Year  \
# 0                                   100.0
# 1                                   100.0
# 2                                    96.0
# 3                                   100.0
# 4                                   100.0
#
#    Acceptable Streets % - Previous Fiscal Quarter  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Acceptable Sidewalks % - Previous Fiscal Quarter
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
rating_og['Month'].unique()
# Out:
# array(['2020 / 08', '2018 / 10', '2018 / 09', '2018 / 08', '2018 / 07',
#        '2018 / 06', '2018 / 05', '2018 / 04', '2018 / 03', '2018 / 02',
#        '2018 / 01', '2017 / 12', '2017 / 11', '2017 / 10', '2017 / 09',
#        '2017 / 08', '2017 / 07', '2017 / 06', '2017 / 05', '2017 / 04',
#        '2017 / 03', '2017 / 02', '2017 / 01', '2020 / 09', '2021 / 04',
#        '2020 / 10', '2020 / 11', '2021 / 05', '2020 / 12', '2021 / 01',
#        '2021 / 03', '2021 / 02', '2021 / 06', '2021 / 08', '2021 / 10',
#        '2021 / 09', '2021 / 07'], dtype=object)

# %%
rating = rating_og.drop(['Borough','Community Board','Cleaning Section'],axis=1)

# %% [markdown]
# ### Temporal Dimension

# %%
rating['Month']=pd.to_datetime(rating['Month'], format='%Y / %m')
rating
# Out:
#           Month District  Acceptable Streets %  Acceptable Sidewalks %  \
# 0    2020-08-01     MN01                100.00                   100.0
# 1    2020-08-01     MN01                100.00                   100.0
# 2    2020-08-01     MN10                 88.00                   100.0
# 3    2020-08-01     MN10                 91.67                   100.0
# 4    2020-08-01     MN10                 96.00                    96.0
# ...         ...      ...                   ...                     ...
# 8615 2021-07-01     SI02                100.00                   100.0
# 8616 2021-07-01     SI03                100.00                   100.0
# 8617 2021-07-01     SI03                100.00                   100.0
# 8618 2021-07-01     SI03                100.00                   100.0
# 8619 2021-07-01     SI03                100.00                   100.0
#
#       Acceptable Streets % - Previous Month  \
# 0                                       NaN
# 1                                       NaN
# 2                                     76.00
# 3                                     60.87
# 4                                     56.00
# ...                                     ...
# 8615                                 100.00
# 8616                                 100.00
# 8617                                 100.00
# 8618                                 100.00
# 8619                                 100.00
#
#       Acceptable Sidewalks % - Previous Month  \
# 0                                         NaN
# 1                                         NaN
# 2                                        92.0
# 3                                       100.0
# 4                                        96.0
# ...                                       ...
# 8615                                    100.0
# 8616                                    100.0
# 8617                                    100.0
# 8618                                    100.0
# 8619                                    100.0
#
#       Acceptable Streets % - Previous Year  \
# 0                                    96.15
# 1                                   100.00
# 2                                    92.00
# 3                                    96.30
# 4                                   100.00
# ...                                    ...
# 8615                                100.00
# 8616                                100.00
# 8617                                100.00
# 8618                                100.00
# 8619                                100.00
#
#       Acceptable Sidewalks % - Previous Year  \
# 0                                      100.0
# 1                                      100.0
# 2                                       96.0
# 3                                      100.0
# 4                                      100.0
# ...                                      ...
# 8615                                   100.0
# 8616                                   100.0
# 8617                                   100.0
# 8618                                   100.0
# 8619                                   100.0
#
#       Acceptable Streets % - Previous Fiscal Quarter  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8615                                           100.0
# 8616                                           100.0
# 8617                                           100.0
# 8618                                           100.0
# 8619                                           100.0
#
#       Acceptable Sidewalks % - Previous Fiscal Quarter
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8615                                             100.0
# 8616                                             100.0
# 8617                                             100.0
# 8618                                             100.0
# 8619                                             100.0
#
# [8620 rows x 10 columns]

# %%
rating = rating.sort_values(by='Month')
rating
# Out:
#           Month District  Acceptable Streets %  Acceptable Sidewalks %  \
# 5208 2017-01-01     QE11                100.00                   94.74
# 5381 2017-01-01     SI03                100.00                  100.00
# 5380 2017-01-01    BKN16                 98.08                   94.23
# 5379 2017-01-01     QW01                 93.10                   93.10
# 5378 2017-01-01     QW02                 98.51                   94.03
# ...         ...      ...                   ...                     ...
# 8044 2021-10-01    BKN17                100.00                   92.30
# 7933 2021-10-01     MN01                   NaN                     NaN
# 7958 2021-10-01     MN05                   NaN                     NaN
# 7959 2021-10-01     MN06                 88.20                  100.00
# 8102 2021-10-01     QE12                100.00                  100.00
#
#       Acceptable Streets % - Previous Month  \
# 5208                                 100.00
# 5381                                 100.00
# 5380                                  80.00
# 5379                                  97.14
# 5378                                  93.75
# ...                                     ...
# 8044                                    NaN
# 7933                                    NaN
# 7958                                    NaN
# 7959                                 100.00
# 8102                                  76.20
#
#       Acceptable Sidewalks % - Previous Month  \
# 5208                                    100.0
# 5381                                    100.0
# 5380                                     96.0
# 5379                                    100.0
# 5378                                     95.0
# ...                                       ...
# 8044                                      NaN
# 7933                                      NaN
# 7958                                      NaN
# 7959                                    100.0
# 8102                                     95.2
#
#       Acceptable Streets % - Previous Year  \
# 5208                                100.00
# 5381                                100.00
# 5380                                100.00
# 5379                                 91.43
# 5378                                 96.15
# ...                                    ...
# 8044                                100.00
# 7933                                 96.90
# 7958                                100.00
# 7959                                 97.00
# 8102                                 83.30
#
#       Acceptable Sidewalks % - Previous Year  \
# 5208                                  100.00
# 5381                                  100.00
# 5380                                   88.00
# 5379                                   94.29
# 5378                                   93.59
# ...                                      ...
# 8044                                  100.00
# 7933                                   96.90
# 7958                                  100.00
# 7959                                   96.90
# 8102                                  100.00
#
#       Acceptable Streets % - Previous Fiscal Quarter  \
# 5208                                          100.00
# 5381                                          100.00
# 5380                                           92.00
# 5379                                           97.14
# 5378                                           95.00
# ...                                              ...
# 8044                                          100.00
# 7933                                          100.00
# 7958                                          100.00
# 7959                                          100.00
# 8102                                             NaN
#
#       Acceptable Sidewalks % - Previous Fiscal Quarter
# 5208                                            100.00
# 5381                                            100.00
# 5380                                             84.00
# 5379                                             97.14
# 5378                                             95.00
# ...                                                ...
# 8044                                            100.00
# 7933                                            100.00
# 7958                                            100.00
# 7959                                            100.00
# 8102                                               NaN
#
# [8620 rows x 10 columns]

# %%
#note that the latest date that they collected rating was October, 2021

# %%
#rating.to_csv('rating.csv')
